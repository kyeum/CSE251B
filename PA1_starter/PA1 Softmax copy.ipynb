# %% [markdown]
# ## Softmax Regression

# %%
import os
os.getenv('CUDA_PATH')
# Out:
# 'C:\\Program Files\\NVIDIA GPU Computing Toolkit\\CUDA\\v10.2'

# %%
# import numpy as np
import cupy as np
import matplotlib.pyplot as plt
from pca import PCA
import argparse
import network
import os, random, sys
from data import traffic_sign, generate_k_fold_set, onehot_encode, onehot_decode, z_score_normalize, append_bias
from model.softmax import SoftmaxRegression
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cupy\__init__.py in <module>
#      17 try:
# ---> 18     from cupy import _core  # NOQA
#      19 except ImportError as e:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cupy\_core\__init__.py in <module>
# ----> 1 from cupy._core import core  # NOQA
#       2 from cupy._core import fusion  # NOQA
#       3 from cupy._core import internal  # NOQA
#
# cupy\_core\core.pyx in init cupy._core.core()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cupy\cuda\__init__.py in <module>
#       7 from cupy._environment import get_hipcc_path  # NOQA
# ----> 8 from cupy.cuda import compiler  # NOQA
#       9 from cupy.cuda import device  # NOQA
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cupy\cuda\compiler.py in <module>
#      12
# ---> 13 from cupy.cuda import device
#      14 from cupy.cuda import function
#
# cupy\cuda\device.pyx in init cupy.cuda.device()
#
# ImportError: DLL load failed while importing runtime: The specified module could not be found.
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12604/1530283703.py in <module>
#       1 # import numpy as np
# ----> 2 import cupy as np
#       3 import matplotlib.pyplot as plt
#       4 from pca import PCA
#       5 import argparse
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\cupy\__init__.py in <module>
#      18     from cupy import _core  # NOQA
#      19 except ImportError as e:
# ---> 20     raise ImportError(f'''
#      21 ================================================================
#      22 {_environment._diagnose_import_error()}
#
# ImportError:
# ================================================================
# Failed to import CuPy.
#
# If you installed CuPy via wheels (cupy-cudaXXX or cupy-rocm-X-X), make sure that the package matches with the version of CUDA or ROCm installed.
#
# On Linux, you may need to set LD_LIBRARY_PATH environment variable depending on how you installed CUDA/ROCm.
# On Windows, try setting CUDA_PATH environment variable.
#
# Check the Installation Guide for details:
#   https://docs.cupy.dev/en/latest/install.html
#
# Original error:
#   ImportError: DLL load failed while importing runtime: The specified module could not be found.
# ================================================================

# %%
### Q6(b) - Stochastic Gradient Descent

print("Q6(b) - Stochastic Gradient Descent")

# (i)
# Load aligned data
X, y = traffic_sign(True)
X = X.astype(np.float32) # cast to float32 as float64 running out of memory
X = z_score_normalize(X) 

# Softmax Regression Parameters
lr = 0.1
num_features = X.shape[1]
num_classes = y.max() + 1

train_loss_record = []
train_accuracy_record = []
holdout_loss_record = []
holdout_accuracy_record = []
test_accuracy_record = []

k=10
# PCA number of principal components
n_components = 300

first_plot = True

num_epochs = 300
epochs_print = [50, 100, 150, 200, 250, 300]

cur_fold = 0

total_test_loss = 0

for train, valid, test in generate_k_fold_set((X, y), k = 10):
    print("Cur fold:", cur_fold)
    train_data, train_label = train
    valid_data, valid_label = valid
    test_data, test_label = test
    
    # Project data onto principal components
    pca = PCA(n_components)
    projected = pca.fit_transform(train_data)
    
    # Plot principal components
    if first_plot == True : 
        pca.plot_PC()
        first_plot = False
    train_d = append_bias(projected)     
    valid_d = append_bias(pca.PCA_generate(valid_data))
    test_d = append_bias(pca.PCA_generate(test_data))

    softmax_model = SoftmaxRegression(lr, n_components, num_classes)

    valid_label_onehot = onehot_encode(valid_label)
    test_label_onehot = onehot_encode(test_label)

    # SGD
    for epoch in range(num_epochs):
        # Shuffle indices
        indices = np.arange(len(train_d))
        indices = np.random.shuffle(indices)

        train_d = train_d[indices].squeeze(0)
        train_label = train_label[indices].squeeze(0)
        
        # Onehot encode labels
        y_true = onehot_encode(train_label)
            
        # Iterate over each example
        for i in range(len(train_d)):
            cur_ex = train_d[i][np.newaxis, :]
            cur_label = y_true[i][np.newaxis, :]
            y_hat = softmax_model.model(cur_ex)

            # Update Weights
            softmax_model.update_weights(cur_ex, cur_label, y_hat)

        # Training Loss
        y_hat = softmax_model.model(train_d)

        raw_train_loss = softmax_model.cross_entropy(y_true, y_hat)
        train_loss_norm = raw_train_loss / len(train_d) / num_classes

        train_loss_record.append(train_loss_norm)

        train_accuracy = softmax_model.accuracy(y_true, y_hat)
        train_accuracy_record.append(train_accuracy)

        # Validation Loss
        holdout_y = softmax_model.model(valid_d)

        holdout_loss = softmax_model.cross_entropy(valid_label_onehot, holdout_y)
        holdout_loss_norm = holdout_loss / len(valid_d) / num_classes # holdout loss normalized by # examples and classes
        holdout_loss_record.append(holdout_loss_norm)

        holdout_accuracy = softmax_model.accuracy(holdout_y, valid_label_onehot)
        holdout_accuracy_record.append(holdout_accuracy)

        if holdout_accuracy >= max(holdout_accuracy_record[cur_fold * num_epochs:]):
            best_w = softmax_model.W

        
        # if (epoch + 1) in epochs_print:
        print(f' epoch: {epoch + 1}, train accuracy: {train_accuracy:.4f}, train_loss_norm:{train_loss_norm:.4f}, '\
            f'valid_acc: {holdout_accuracy:.4f}, valid_loss_norm: {holdout_loss_norm:.4f}')

    # Run on Test Dataset
    test_y = softmax_model.model_w(test_d, best_w)

    test_accuracy = softmax_model.accuracy(test_y, test_label_onehot)

    print(f'Test accuracy: {test_accuracy:.4f}')

    test_accuracy_record.append(test_accuracy)

    raw_test_loss = softmax_model.cross_entropy(test_label_onehot, test_y)
    test_loss_norm = raw_test_loss / len(test_d) / num_classes
    total_test_loss += test_loss_norm
    print(f"Test loss norm: {test_loss_norm:.4f}")

    cur_fold += 1

print(f'Average test accuracy over {k} folds: {np.mean(test_accuracy_record):.4f} (+/- {np.std(test_accuracy_record):.4f})')
print(f'Average test loss per example and class over {k} folds: {total_test_loss / k}')
# Out:
# Q6(b) - Stochastic Gradient Descent
# Cur fold: 0
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 1, train accuracy: 0.7915, train_loss_norm:0.0867, valid_acc: 0.7706, valid_loss_norm: 0.0867
#  epoch: 2, train accuracy: 0.7915, train_loss_norm:0.0859, valid_acc: 0.7706, valid_loss_norm: 0.0859
#  epoch: 3, train accuracy: 0.7915, train_loss_norm:0.0851, valid_acc: 0.7706, valid_loss_norm: 0.0852
#  epoch: 4, train accuracy: 0.7915, train_loss_norm:0.0844, valid_acc: 0.7706, valid_loss_norm: 0.0845
#  epoch: 5, train accuracy: 0.7915, train_loss_norm:0.0836, valid_acc: 0.7709, valid_loss_norm: 0.0837
#  epoch: 6, train accuracy: 0.7915, train_loss_norm:0.0829, valid_acc: 0.7709, valid_loss_norm: 0.0830
#  epoch: 7, train accuracy: 0.7915, train_loss_norm:0.0821, valid_acc: 0.7709, valid_loss_norm: 0.0822
#  epoch: 8, train accuracy: 0.7915, train_loss_norm:0.0814, valid_acc: 0.7712, valid_loss_norm: 0.0815
#  epoch: 9, train accuracy: 0.7915, train_loss_norm:0.0806, valid_acc: 0.7712, valid_loss_norm: 0.0808
#  epoch: 10, train accuracy: 0.7915, train_loss_norm:0.0799, valid_acc: 0.7712, valid_loss_norm: 0.0801
#  epoch: 11, train accuracy: 0.7915, train_loss_norm:0.0792, valid_acc: 0.7712, valid_loss_norm: 0.0794
#  epoch: 12, train accuracy: 0.7915, train_loss_norm:0.0785, valid_acc: 0.7712, valid_loss_norm: 0.0787
#  epoch: 13, train accuracy: 0.7916, train_loss_norm:0.0777, valid_acc: 0.7712, valid_loss_norm: 0.0780
#  epoch: 14, train accuracy: 0.7916, train_loss_norm:0.0770, valid_acc: 0.7718, valid_loss_norm: 0.0773
#  epoch: 15, train accuracy: 0.7917, train_loss_norm:0.0763, valid_acc: 0.7721, valid_loss_norm: 0.0766
#  epoch: 16, train accuracy: 0.7918, train_loss_norm:0.0756, valid_acc: 0.7721, valid_loss_norm: 0.0759
#  epoch: 17, train accuracy: 0.7918, train_loss_norm:0.0749, valid_acc: 0.7723, valid_loss_norm: 0.0752
#  epoch: 18, train accuracy: 0.7920, train_loss_norm:0.0742, valid_acc: 0.7721, valid_loss_norm: 0.0745
#  epoch: 19, train accuracy: 0.7921, train_loss_norm:0.0736, valid_acc: 0.7723, valid_loss_norm: 0.0739
#  epoch: 20, train accuracy: 0.7923, train_loss_norm:0.0729, valid_acc: 0.7726, valid_loss_norm: 0.0732
#  epoch: 21, train accuracy: 0.7924, train_loss_norm:0.0722, valid_acc: 0.7726, valid_loss_norm: 0.0726
#  epoch: 22, train accuracy: 0.7928, train_loss_norm:0.0716, valid_acc: 0.7723, valid_loss_norm: 0.0720
#  epoch: 23, train accuracy: 0.7928, train_loss_norm:0.0709, valid_acc: 0.7723, valid_loss_norm: 0.0713
#  epoch: 24, train accuracy: 0.7931, train_loss_norm:0.0703, valid_acc: 0.7723, valid_loss_norm: 0.0707
#  epoch: 25, train accuracy: 0.7932, train_loss_norm:0.0697, valid_acc: 0.7721, valid_loss_norm: 0.0701
#  epoch: 26, train accuracy: 0.7934, train_loss_norm:0.0691, valid_acc: 0.7721, valid_loss_norm: 0.0695
#  epoch: 27, train accuracy: 0.7938, train_loss_norm:0.0685, valid_acc: 0.7729, valid_loss_norm: 0.0689
#  epoch: 28, train accuracy: 0.7939, train_loss_norm:0.0679, valid_acc: 0.7732, valid_loss_norm: 0.0683
#  epoch: 29, train accuracy: 0.7940, train_loss_norm:0.0673, valid_acc: 0.7732, valid_loss_norm: 0.0677
#  epoch: 30, train accuracy: 0.7943, train_loss_norm:0.0667, valid_acc: 0.7732, valid_loss_norm: 0.0672
#  epoch: 31, train accuracy: 0.7945, train_loss_norm:0.0661, valid_acc: 0.7735, valid_loss_norm: 0.0666
#  epoch: 32, train accuracy: 0.7948, train_loss_norm:0.0656, valid_acc: 0.7735, valid_loss_norm: 0.0661
#  epoch: 33, train accuracy: 0.7950, train_loss_norm:0.0650, valid_acc: 0.7735, valid_loss_norm: 0.0655
#  epoch: 34, train accuracy: 0.7952, train_loss_norm:0.0645, valid_acc: 0.7738, valid_loss_norm: 0.0650
#  epoch: 35, train accuracy: 0.7952, train_loss_norm:0.0639, valid_acc: 0.7741, valid_loss_norm: 0.0645
#  epoch: 36, train accuracy: 0.7954, train_loss_norm:0.0634, valid_acc: 0.7746, valid_loss_norm: 0.0640
#  epoch: 37, train accuracy: 0.7956, train_loss_norm:0.0629, valid_acc: 0.7749, valid_loss_norm: 0.0635
#  epoch: 38, train accuracy: 0.7957, train_loss_norm:0.0624, valid_acc: 0.7752, valid_loss_norm: 0.0630
#  epoch: 39, train accuracy: 0.7960, train_loss_norm:0.0619, valid_acc: 0.7752, valid_loss_norm: 0.0625
#  epoch: 40, train accuracy: 0.7963, train_loss_norm:0.0614, valid_acc: 0.7755, valid_loss_norm: 0.0621
#  epoch: 41, train accuracy: 0.7965, train_loss_norm:0.0610, valid_acc: 0.7755, valid_loss_norm: 0.0616
#  epoch: 42, train accuracy: 0.7966, train_loss_norm:0.0605, valid_acc: 0.7755, valid_loss_norm: 0.0611
#  epoch: 43, train accuracy: 0.7968, train_loss_norm:0.0600, valid_acc: 0.7761, valid_loss_norm: 0.0607
#  epoch: 44, train accuracy: 0.7971, train_loss_norm:0.0596, valid_acc: 0.7755, valid_loss_norm: 0.0603
#  epoch: 45, train accuracy: 0.7975, train_loss_norm:0.0592, valid_acc: 0.7764, valid_loss_norm: 0.0598
#  epoch: 46, train accuracy: 0.7977, train_loss_norm:0.0587, valid_acc: 0.7767, valid_loss_norm: 0.0594
#  epoch: 47, train accuracy: 0.7979, train_loss_norm:0.0583, valid_acc: 0.7764, valid_loss_norm: 0.0590
#  epoch: 48, train accuracy: 0.7980, train_loss_norm:0.0579, valid_acc: 0.7769, valid_loss_norm: 0.0586
#  epoch: 49, train accuracy: 0.7982, train_loss_norm:0.0575, valid_acc: 0.7769, valid_loss_norm: 0.0582
#  epoch: 50, train accuracy: 0.7985, train_loss_norm:0.0571, valid_acc: 0.7778, valid_loss_norm: 0.0578
#  epoch: 51, train accuracy: 0.7990, train_loss_norm:0.0567, valid_acc: 0.7778, valid_loss_norm: 0.0574
#  epoch: 52, train accuracy: 0.7993, train_loss_norm:0.0563, valid_acc: 0.7790, valid_loss_norm: 0.0571
#  epoch: 53, train accuracy: 0.7996, train_loss_norm:0.0559, valid_acc: 0.7792, valid_loss_norm: 0.0567
#  epoch: 54, train accuracy: 0.7998, train_loss_norm:0.0555, valid_acc: 0.7801, valid_loss_norm: 0.0563
#  epoch: 55, train accuracy: 0.8003, train_loss_norm:0.0552, valid_acc: 0.7810, valid_loss_norm: 0.0560
#  epoch: 56, train accuracy: 0.8004, train_loss_norm:0.0548, valid_acc: 0.7815, valid_loss_norm: 0.0556
#  epoch: 57, train accuracy: 0.8007, train_loss_norm:0.0545, valid_acc: 0.7818, valid_loss_norm: 0.0553
#  epoch: 58, train accuracy: 0.8008, train_loss_norm:0.0541, valid_acc: 0.7824, valid_loss_norm: 0.0550
#  epoch: 59, train accuracy: 0.8016, train_loss_norm:0.0538, valid_acc: 0.7821, valid_loss_norm: 0.0546
#  epoch: 60, train accuracy: 0.8017, train_loss_norm:0.0535, valid_acc: 0.7827, valid_loss_norm: 0.0543
#  epoch: 61, train accuracy: 0.8019, train_loss_norm:0.0531, valid_acc: 0.7830, valid_loss_norm: 0.0540
#  epoch: 62, train accuracy: 0.8022, train_loss_norm:0.0528, valid_acc: 0.7833, valid_loss_norm: 0.0537
#  epoch: 63, train accuracy: 0.8024, train_loss_norm:0.0525, valid_acc: 0.7833, valid_loss_norm: 0.0534
#  epoch: 64, train accuracy: 0.8029, train_loss_norm:0.0522, valid_acc: 0.7850, valid_loss_norm: 0.0531
#  epoch: 65, train accuracy: 0.8034, train_loss_norm:0.0519, valid_acc: 0.7859, valid_loss_norm: 0.0528
#  epoch: 66, train accuracy: 0.8038, train_loss_norm:0.0516, valid_acc: 0.7856, valid_loss_norm: 0.0525
#  epoch: 67, train accuracy: 0.8043, train_loss_norm:0.0513, valid_acc: 0.7859, valid_loss_norm: 0.0522
#  epoch: 68, train accuracy: 0.8046, train_loss_norm:0.0510, valid_acc: 0.7859, valid_loss_norm: 0.0519
#  epoch: 69, train accuracy: 0.8050, train_loss_norm:0.0507, valid_acc: 0.7864, valid_loss_norm: 0.0517
#  epoch: 70, train accuracy: 0.8055, train_loss_norm:0.0504, valid_acc: 0.7867, valid_loss_norm: 0.0514
#  epoch: 71, train accuracy: 0.8055, train_loss_norm:0.0501, valid_acc: 0.7873, valid_loss_norm: 0.0511
#  epoch: 72, train accuracy: 0.8059, train_loss_norm:0.0499, valid_acc: 0.7876, valid_loss_norm: 0.0509
#  epoch: 73, train accuracy: 0.8061, train_loss_norm:0.0496, valid_acc: 0.7884, valid_loss_norm: 0.0506
#  epoch: 74, train accuracy: 0.8065, train_loss_norm:0.0493, valid_acc: 0.7890, valid_loss_norm: 0.0503
#  epoch: 75, train accuracy: 0.8069, train_loss_norm:0.0491, valid_acc: 0.7896, valid_loss_norm: 0.0501
#  epoch: 76, train accuracy: 0.8072, train_loss_norm:0.0488, valid_acc: 0.7905, valid_loss_norm: 0.0498
#  epoch: 77, train accuracy: 0.8078, train_loss_norm:0.0486, valid_acc: 0.7910, valid_loss_norm: 0.0496
#  epoch: 78, train accuracy: 0.8083, train_loss_norm:0.0483, valid_acc: 0.7916, valid_loss_norm: 0.0494
#  epoch: 79, train accuracy: 0.8088, train_loss_norm:0.0481, valid_acc: 0.7916, valid_loss_norm: 0.0491
#  epoch: 80, train accuracy: 0.8093, train_loss_norm:0.0478, valid_acc: 0.7919, valid_loss_norm: 0.0489
#  epoch: 81, train accuracy: 0.8096, train_loss_norm:0.0476, valid_acc: 0.7922, valid_loss_norm: 0.0487
#  epoch: 82, train accuracy: 0.8099, train_loss_norm:0.0474, valid_acc: 0.7919, valid_loss_norm: 0.0484
#  epoch: 83, train accuracy: 0.8102, train_loss_norm:0.0472, valid_acc: 0.7928, valid_loss_norm: 0.0482
#  epoch: 84, train accuracy: 0.8106, train_loss_norm:0.0469, valid_acc: 0.7936, valid_loss_norm: 0.0480
#  epoch: 85, train accuracy: 0.8106, train_loss_norm:0.0467, valid_acc: 0.7942, valid_loss_norm: 0.0478
#  epoch: 86, train accuracy: 0.8111, train_loss_norm:0.0465, valid_acc: 0.7948, valid_loss_norm: 0.0476
#  epoch: 87, train accuracy: 0.8114, train_loss_norm:0.0463, valid_acc: 0.7951, valid_loss_norm: 0.0474
#  epoch: 88, train accuracy: 0.8117, train_loss_norm:0.0461, valid_acc: 0.7953, valid_loss_norm: 0.0472
#  epoch: 89, train accuracy: 0.8120, train_loss_norm:0.0458, valid_acc: 0.7953, valid_loss_norm: 0.0470
#  epoch: 90, train accuracy: 0.8123, train_loss_norm:0.0456, valid_acc: 0.7965, valid_loss_norm: 0.0468
#  epoch: 91, train accuracy: 0.8123, train_loss_norm:0.0454, valid_acc: 0.7962, valid_loss_norm: 0.0466
#  epoch: 92, train accuracy: 0.8126, train_loss_norm:0.0452, valid_acc: 0.7962, valid_loss_norm: 0.0464
#  epoch: 93, train accuracy: 0.8129, train_loss_norm:0.0450, valid_acc: 0.7962, valid_loss_norm: 0.0462
#  epoch: 94, train accuracy: 0.8133, train_loss_norm:0.0448, valid_acc: 0.7965, valid_loss_norm: 0.0460
#  epoch: 95, train accuracy: 0.8135, train_loss_norm:0.0446, valid_acc: 0.7971, valid_loss_norm: 0.0458
#  epoch: 96, train accuracy: 0.8137, train_loss_norm:0.0445, valid_acc: 0.7971, valid_loss_norm: 0.0456
#  epoch: 97, train accuracy: 0.8138, train_loss_norm:0.0443, valid_acc: 0.7965, valid_loss_norm: 0.0454
#  epoch: 98, train accuracy: 0.8142, train_loss_norm:0.0441, valid_acc: 0.7965, valid_loss_norm: 0.0453
#  epoch: 99, train accuracy: 0.8146, train_loss_norm:0.0439, valid_acc: 0.7968, valid_loss_norm: 0.0451
#  epoch: 100, train accuracy: 0.8147, train_loss_norm:0.0437, valid_acc: 0.7971, valid_loss_norm: 0.0449
#  epoch: 101, train accuracy: 0.8152, train_loss_norm:0.0435, valid_acc: 0.7971, valid_loss_norm: 0.0447
#  epoch: 102, train accuracy: 0.8155, train_loss_norm:0.0434, valid_acc: 0.7971, valid_loss_norm: 0.0446
#  epoch: 103, train accuracy: 0.8156, train_loss_norm:0.0432, valid_acc: 0.7974, valid_loss_norm: 0.0444
#  epoch: 104, train accuracy: 0.8158, train_loss_norm:0.0430, valid_acc: 0.7976, valid_loss_norm: 0.0442
#  epoch: 105, train accuracy: 0.8161, train_loss_norm:0.0428, valid_acc: 0.7976, valid_loss_norm: 0.0441
#  epoch: 106, train accuracy: 0.8164, train_loss_norm:0.0427, valid_acc: 0.7976, valid_loss_norm: 0.0439
#  epoch: 107, train accuracy: 0.8168, train_loss_norm:0.0425, valid_acc: 0.7985, valid_loss_norm: 0.0437
#  epoch: 108, train accuracy: 0.8171, train_loss_norm:0.0423, valid_acc: 0.7991, valid_loss_norm: 0.0436
#  epoch: 109, train accuracy: 0.8176, train_loss_norm:0.0422, valid_acc: 0.7994, valid_loss_norm: 0.0434
#  epoch: 110, train accuracy: 0.8179, train_loss_norm:0.0420, valid_acc: 0.7994, valid_loss_norm: 0.0433
#  epoch: 111, train accuracy: 0.8182, train_loss_norm:0.0419, valid_acc: 0.7994, valid_loss_norm: 0.0431
#  epoch: 112, train accuracy: 0.8184, train_loss_norm:0.0417, valid_acc: 0.7994, valid_loss_norm: 0.0430
#  epoch: 113, train accuracy: 0.8184, train_loss_norm:0.0415, valid_acc: 0.7997, valid_loss_norm: 0.0428
#  epoch: 114, train accuracy: 0.8184, train_loss_norm:0.0414, valid_acc: 0.7997, valid_loss_norm: 0.0427
#  epoch: 115, train accuracy: 0.8187, train_loss_norm:0.0412, valid_acc: 0.8005, valid_loss_norm: 0.0425
#  epoch: 116, train accuracy: 0.8191, train_loss_norm:0.0411, valid_acc: 0.8011, valid_loss_norm: 0.0424
#  epoch: 117, train accuracy: 0.8194, train_loss_norm:0.0409, valid_acc: 0.8011, valid_loss_norm: 0.0422
#  epoch: 118, train accuracy: 0.8197, train_loss_norm:0.0408, valid_acc: 0.8011, valid_loss_norm: 0.0421
#  epoch: 119, train accuracy: 0.8199, train_loss_norm:0.0406, valid_acc: 0.8017, valid_loss_norm: 0.0419
#  epoch: 120, train accuracy: 0.8202, train_loss_norm:0.0405, valid_acc: 0.8020, valid_loss_norm: 0.0418
#  epoch: 121, train accuracy: 0.8205, train_loss_norm:0.0404, valid_acc: 0.8025, valid_loss_norm: 0.0417
#  epoch: 122, train accuracy: 0.8206, train_loss_norm:0.0402, valid_acc: 0.8025, valid_loss_norm: 0.0415
#  epoch: 123, train accuracy: 0.8208, train_loss_norm:0.0401, valid_acc: 0.8025, valid_loss_norm: 0.0414
#  epoch: 124, train accuracy: 0.8209, train_loss_norm:0.0399, valid_acc: 0.8022, valid_loss_norm: 0.0413
#  epoch: 125, train accuracy: 0.8213, train_loss_norm:0.0398, valid_acc: 0.8020, valid_loss_norm: 0.0411
#  epoch: 126, train accuracy: 0.8216, train_loss_norm:0.0397, valid_acc: 0.8025, valid_loss_norm: 0.0410
#  epoch: 127, train accuracy: 0.8217, train_loss_norm:0.0395, valid_acc: 0.8025, valid_loss_norm: 0.0409
#  epoch: 128, train accuracy: 0.8221, train_loss_norm:0.0394, valid_acc: 0.8034, valid_loss_norm: 0.0407
#  epoch: 129, train accuracy: 0.8223, train_loss_norm:0.0393, valid_acc: 0.8037, valid_loss_norm: 0.0406
#  epoch: 130, train accuracy: 0.8225, train_loss_norm:0.0392, valid_acc: 0.8040, valid_loss_norm: 0.0405
#  epoch: 131, train accuracy: 0.8226, train_loss_norm:0.0390, valid_acc: 0.8037, valid_loss_norm: 0.0404
#  epoch: 132, train accuracy: 0.8227, train_loss_norm:0.0389, valid_acc: 0.8043, valid_loss_norm: 0.0402
#  epoch: 133, train accuracy: 0.8229, train_loss_norm:0.0388, valid_acc: 0.8043, valid_loss_norm: 0.0401
#  epoch: 134, train accuracy: 0.8233, train_loss_norm:0.0386, valid_acc: 0.8043, valid_loss_norm: 0.0400
#  epoch: 135, train accuracy: 0.8237, train_loss_norm:0.0385, valid_acc: 0.8040, valid_loss_norm: 0.0399
#  epoch: 136, train accuracy: 0.8239, train_loss_norm:0.0384, valid_acc: 0.8043, valid_loss_norm: 0.0398
#  epoch: 137, train accuracy: 0.8240, train_loss_norm:0.0383, valid_acc: 0.8045, valid_loss_norm: 0.0397
#  epoch: 138, train accuracy: 0.8241, train_loss_norm:0.0382, valid_acc: 0.8045, valid_loss_norm: 0.0395
#  epoch: 139, train accuracy: 0.8245, train_loss_norm:0.0380, valid_acc: 0.8043, valid_loss_norm: 0.0394
#  epoch: 140, train accuracy: 0.8247, train_loss_norm:0.0379, valid_acc: 0.8040, valid_loss_norm: 0.0393
#  epoch: 141, train accuracy: 0.8249, train_loss_norm:0.0378, valid_acc: 0.8043, valid_loss_norm: 0.0392
#  epoch: 142, train accuracy: 0.8253, train_loss_norm:0.0377, valid_acc: 0.8043, valid_loss_norm: 0.0391
#  epoch: 143, train accuracy: 0.8256, train_loss_norm:0.0376, valid_acc: 0.8043, valid_loss_norm: 0.0390
#  epoch: 144, train accuracy: 0.8257, train_loss_norm:0.0375, valid_acc: 0.8040, valid_loss_norm: 0.0389
#  epoch: 145, train accuracy: 0.8259, train_loss_norm:0.0374, valid_acc: 0.8040, valid_loss_norm: 0.0388
#  epoch: 146, train accuracy: 0.8259, train_loss_norm:0.0373, valid_acc: 0.8043, valid_loss_norm: 0.0387
#  epoch: 147, train accuracy: 0.8260, train_loss_norm:0.0371, valid_acc: 0.8040, valid_loss_norm: 0.0385
#  epoch: 148, train accuracy: 0.8262, train_loss_norm:0.0370, valid_acc: 0.8040, valid_loss_norm: 0.0384
#  epoch: 149, train accuracy: 0.8265, train_loss_norm:0.0369, valid_acc: 0.8040, valid_loss_norm: 0.0383
#  epoch: 150, train accuracy: 0.8268, train_loss_norm:0.0368, valid_acc: 0.8040, valid_loss_norm: 0.0382
#  epoch: 151, train accuracy: 0.8270, train_loss_norm:0.0367, valid_acc: 0.8043, valid_loss_norm: 0.0381
#  epoch: 152, train accuracy: 0.8273, train_loss_norm:0.0366, valid_acc: 0.8043, valid_loss_norm: 0.0380
#  epoch: 153, train accuracy: 0.8275, train_loss_norm:0.0365, valid_acc: 0.8045, valid_loss_norm: 0.0379
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8344/2098488244.py in <module>
#      72             cur_ex = train_d[i][np.newaxis, :]
#      73             cur_label = y_true[i][np.newaxis, :]
# ---> 74             y_hat = softmax_model.model(cur_ex)
#      75
#      76             # Update Weights
#
# c:\Users\Victor\OneDrive\Documents\UCSD\0CSE251B\hw1\CSE251B\cse251b_PA1_starter\model\softmax.py in model(self, X)
#      32         Model Network for Softmax Regression
#      33         '''
# ---> 34         logits = np.dot(X, self.W)
#      35         return self.softmax(logits)
#      36
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
plt.clf()

fig, axs = plt.subplots(2, 1, constrained_layout=True)
fig.set_size_inches(18.5, 10.5)

epochs_error_bar = [50, 100, 150, 200, 250, 300] # 1-indexed
epochs_error_bar_0 = [epoch - 1 for epoch in epochs_error_bar] # 0-indexed

# Plot Loss
average_train_loss = average_out_data_k(train_loss_record)
train_loss_error_bar_y = [average_train_loss[epoch] for epoch in epochs_error_bar_0]
train_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_loss_record, epoch)) for epoch in epochs_error_bar_0]


average_valid_loss = average_out_data_k(holdout_loss_record)
valid_loss_error_bar_y = [average_valid_loss[epoch] for epoch in epochs_error_bar_0]
valid_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_loss_record, epoch)) for epoch in epochs_error_bar_0]

axs[0].plot(average_train_loss, '-b', label='Training loss')
axs[0].errorbar(x=epochs_error_bar_0, y=train_loss_error_bar_y, yerr=train_loss_error_bar_yerr, label='Training loss error', fmt='-b', linestyle='')

axs[0].plot(average_valid_loss, '--r', label='Validation loss')
axs[0].errorbar(x=epochs_error_bar_0, y=valid_loss_error_bar_y, yerr=valid_loss_error_bar_yerr, label='Validation loss error', fmt='--r', linestyle='')

axs[0].legend()
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Normalized Loss')
axs[0].set_title('Loss normalized per example and class vs. Epochs')

# Plot Accuracy
average_train_acc = average_out_data_k(train_accuracy_record)
train_acc_error_bar_y = [average_train_acc[epoch] for epoch in epochs_error_bar_0]
train_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

average_valid_acc = average_out_data_k(holdout_accuracy_record)
valid_acc_error_bar_y = [average_valid_acc[epoch] for epoch in epochs_error_bar_0]
valid_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

axs[1].plot(average_train_acc, '-b', label='Training accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=train_acc_error_bar_y, yerr=train_acc_error_bar_yerr, label='Training accuracy error', fmt='-b', linestyle='')

axs[1].plot(average_valid_acc, '--r', label='Validation accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=valid_acc_error_bar_y, yerr=valid_acc_error_bar_yerr, label='Validation accuracy error', fmt='--r', linestyle='')

axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('Accuracy vs. Epochs')

plt.savefig("plots/Q6b_i_lr0-1.png")
plt.close(fig)

# %%
# (ii) Plot Batch vs. Stochastic Gradient Descent
plt.clf()
# plt.set_size_inches(18.5, 10.5)

epochs_error_bar = [50, 100, 150, 200, 250, 300] # 1-indexed
epochs_error_bar_0 = [epoch - 1 for epoch in epochs_error_bar] # 0-indexed

# Plot Loss
average_train_loss = average_out_data_k(train_loss_record)
train_loss_error_bar_y = [average_train_loss[epoch] for epoch in epochs_error_bar_0]
train_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_loss_record, epoch)) for epoch in epochs_error_bar_0]

plt.plot(average_train_loss, '-b', label='Stochastic')
plt.errorbar(x=epochs_error_bar_0, y=train_loss_error_bar_y, yerr=train_loss_error_bar_yerr, label='Stochastic error', fmt='-b', linestyle='')

plt.plot(batch_average_train_loss, '--r', label='Batch')
plt.errorbar(x=epochs_error_bar_0, y=batch_average_train_loss_error_bar_y, yerr=batch_average_train_loss_error_bar_yerr, label='Batch error', fmt='--r', linestyle='')

plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Normalized Loss')
plt.title('Batch vs. Stochastic Normalized Training Loss')

plt.savefig("plots/Q6b_ii_lr0-1.png")

# %%
# ### (c) Visualize the weights

# from matplotlib.pyplot import figure

# def weights2range(w, min=0, max=256):
#     # Scales weights to be between min and max
#     w /= np.max(w)
#     w *= (max)
#     w += min
#     return w

# # Plot image

# weight_visualization_weights = best_w[:-1]

# # Traffic sign classes to be plotted
# ts_classes = [7, 11, 21, 25]

# fig, axs = plt.subplots(4,1) 
# fig.set_size_inches(10, 6)

# for i, ts_class in enumerate(ts_classes):
#     # Get weights for each class
#     class_weights = weight_visualization_weights[:,ts_class].reshape((32, 32))
#     # Scale to [0, 256]
#     img_weights = weights2range(class_weights)
#     # Plot image
#     axs[i].set_title(f'Class {ts_class}')
#     axs[i].imshow(img_weights)

# plt.tight_layout()
# plt.savefig('plots/Q6c_weights.png')
