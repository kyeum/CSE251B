# %% [markdown]
# ## Softmax Regression

# %%
import numpy as np
import matplotlib.pyplot as plt
from pca import PCA
import argparse
import network
import os, random, sys
from data import traffic_sign, generate_k_fold_set, onehot_encode, onehot_decode, z_score_normalize, append_bias
from model.softmax import SoftmaxRegression

# %%
### Q6(a) - Evaluate Network on all 43 traffic signs (aligned dataset)

# Load aligned data
X, y = traffic_sign(True)
X = X.astype(np.float32) # cast to float32 as float64 running out of memory
X = z_score_normalize(X) 

print(X.shape)
print(y.shape)
print(X.dtype)
print(y.dtype)
# Out:
# (34799, 1024)
# (34799,)
# float32
# uint8

# %%
## (i) With PCA on aligned

DEBUG = False

# Softmax Regression Parameters
lr = 0.5
num_features = X.shape[1]
num_classes = y.max() + 1

train_loss_record = []

train_accuracy_record = []

holdout_loss_record = []

holdout_accuracy_record = []

test_accuracy_record = []

# PCA number of principal components
n_components = 300

first_plot = True

num_epochs = 300
epochs_print = [50, 100, 150, 200, 250, 300]

k = 10

total_test_accuracy = 0.0
total_test_loss = 0.0

cur_fold = 0
for train, valid, test in generate_k_fold_set((X, y), k):
    print(f"Current Fold: {cur_fold}")
    train_data, train_label = train
    valid_data, valid_label = valid
    test_data, test_label = test
    
    # Project data onto principal components
    pca = PCA(n_components)
    projected = pca.fit_transform(train_data) # len(train_data) x n_components
    
    # Plot principal components
    if first_plot == True : 
        pca.plot_PC()
        first_plot = False
    train_d = append_bias(projected)     
    valid_d = append_bias(pca.PCA_generate(valid_data))
    test_d = append_bias(pca.PCA_generate(test_data))

    softmax_model = SoftmaxRegression(lr, n_components, num_classes)
    best_w = softmax_model.W

    # Onehot encode labels
    y_true = onehot_encode(train_label)
    valid_label_onehot = onehot_encode(valid_label)
    test_label_onehot = onehot_encode(test_label)
    
    for epoch in range(num_epochs):
        y_hat = softmax_model.model(train_d)
        
        raw_train_loss = softmax_model.cross_entropy(y_true, y_hat)
        train_loss_norm = raw_train_loss / len(train_d) / num_classes # train loss normalized by # examples and classes
        
        train_loss_record.append(train_loss_norm)
        
        train_accuracy = softmax_model.accuracy(y_true, y_hat)
        train_accuracy_record.append(train_accuracy)
        
        holdout_y = softmax_model.model(valid_d)

        holdout_loss = softmax_model.cross_entropy(holdout_y, valid_label_onehot)
        holdout_loss_norm = holdout_loss / len(valid_d) / num_classes # holdout loss normalized by # examples and classes
        holdout_loss_record.append(holdout_loss_norm)

        holdout_accuracy = softmax_model.accuracy(holdout_y, valid_label_onehot)
        holdout_accuracy_record.append(holdout_accuracy)

        if holdout_accuracy >= max(holdout_accuracy_record[cur_fold * num_epochs:]):
            best_w = softmax_model.W

        # Update Weights
        softmax_model.update_weights(train_d, y_true, y_hat)

        if (epoch + 1) in epochs_print:
            print(f' epoch: {epoch + 1}, train accuracy: {train_accuracy:.4f}, train_loss_norm:{train_loss_norm:.4f}, '\
                f'valid_acc: {holdout_accuracy:.4f}, valid_loss_norm: {holdout_loss_norm:.4f}')
            if DEBUG:
                test_y = softmax_model.model_w(test_d, best_w)
                test_y_1 = softmax_model.model(test_d)

                test_accuracy = softmax_model.accuracy(test_y, test_label_onehot)
                test_accuracy_1 = softmax_model.accuracy(test_y_1, test_label_onehot)

                raw_test_loss = softmax_model.cross_entropy(test_y, test_label_onehot)
                test_loss_norm = raw_test_loss / len(test_d) / num_classes

                print(f'MODEL_W: Test accuracy: {test_accuracy:.4f}', f'Test loss norm: {test_loss_norm:.4f}')
                print(f'MODEL: Test accuracy: {test_accuracy_1:.4f}')

    # Run on Test Dataset
    test_y = softmax_model.model_w(test_d, best_w)

    test_accuracy = softmax_model.accuracy(test_y, test_label_onehot)

    print(f'Test accuracy: {test_accuracy:.4f}')

    total_test_accuracy += test_accuracy

    raw_test_loss = softmax_model.cross_entropy(test_y, test_label_onehot)
    test_loss_norm = raw_test_loss / len(test_d) / num_classes
    total_test_loss += test_loss_norm
    print(f"Test loss norm: {test_loss_norm:.4f}")

    cur_fold += 1

print(f'Average test accuracy over {k} folds: {total_test_accuracy / k}')
print(f'Average test loss per example and class over {k} folds: {total_test_loss / k}')
# Out:
# Current Fold: 0
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8408, train_loss_norm:0.0296, valid_acc: 0.8215, valid_loss_norm: 0.0478
#  epoch: 100, train accuracy: 0.8622, train_loss_norm:0.0217, valid_acc: 0.8387, valid_loss_norm: 0.0432
#  epoch: 150, train accuracy: 0.8754, train_loss_norm:0.0182, valid_acc: 0.8508, valid_loss_norm: 0.0399
#  epoch: 200, train accuracy: 0.8853, train_loss_norm:0.0162, valid_acc: 0.8577, valid_loss_norm: 0.0381
#  epoch: 250, train accuracy: 0.8932, train_loss_norm:0.0148, valid_acc: 0.8643, valid_loss_norm: 0.0363
#  epoch: 300, train accuracy: 0.9001, train_loss_norm:0.0137, valid_acc: 0.8704, valid_loss_norm: 0.0347
# Test accuracy: 0.8594
# Test loss norm: 0.0376
# Current Fold: 1
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8426, train_loss_norm:0.0296, valid_acc: 0.8198, valid_loss_norm: 0.0483
#  epoch: 100, train accuracy: 0.8633, train_loss_norm:0.0217, valid_acc: 0.8347, valid_loss_norm: 0.0443
#  epoch: 150, train accuracy: 0.8767, train_loss_norm:0.0182, valid_acc: 0.8431, valid_loss_norm: 0.0420
#  epoch: 200, train accuracy: 0.8865, train_loss_norm:0.0162, valid_acc: 0.8505, valid_loss_norm: 0.0400
#  epoch: 250, train accuracy: 0.8953, train_loss_norm:0.0148, valid_acc: 0.8554, valid_loss_norm: 0.0387
#  epoch: 300, train accuracy: 0.9013, train_loss_norm:0.0137, valid_acc: 0.8597, valid_loss_norm: 0.0376
# Test accuracy: 0.8615
# Test loss norm: 0.0371
# Current Fold: 2
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8439, train_loss_norm:0.0295, valid_acc: 0.8172, valid_loss_norm: 0.0489
#  epoch: 100, train accuracy: 0.8619, train_loss_norm:0.0217, valid_acc: 0.8359, valid_loss_norm: 0.0439
#  epoch: 150, train accuracy: 0.8762, train_loss_norm:0.0182, valid_acc: 0.8462, valid_loss_norm: 0.0412
#  epoch: 200, train accuracy: 0.8854, train_loss_norm:0.0162, valid_acc: 0.8540, valid_loss_norm: 0.0391
#  epoch: 250, train accuracy: 0.8948, train_loss_norm:0.0147, valid_acc: 0.8597, valid_loss_norm: 0.0376
#  epoch: 300, train accuracy: 0.9009, train_loss_norm:0.0137, valid_acc: 0.8635, valid_loss_norm: 0.0366
# Test accuracy: 0.8537
# Test loss norm: 0.0392
# Current Fold: 3
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8417, train_loss_norm:0.0295, valid_acc: 0.8031, valid_loss_norm: 0.0527
#  epoch: 100, train accuracy: 0.8623, train_loss_norm:0.0217, valid_acc: 0.8258, valid_loss_norm: 0.0466
#  epoch: 150, train accuracy: 0.8759, train_loss_norm:0.0182, valid_acc: 0.8393, valid_loss_norm: 0.0430
#  epoch: 200, train accuracy: 0.8858, train_loss_norm:0.0162, valid_acc: 0.8456, valid_loss_norm: 0.0413
#  epoch: 250, train accuracy: 0.8940, train_loss_norm:0.0148, valid_acc: 0.8494, valid_loss_norm: 0.0403
#  epoch: 300, train accuracy: 0.9007, train_loss_norm:0.0137, valid_acc: 0.8560, valid_loss_norm: 0.0386
# Test accuracy: 0.8615
# Test loss norm: 0.0371
# Current Fold: 4
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8414, train_loss_norm:0.0297, valid_acc: 0.8270, valid_loss_norm: 0.0463
#  epoch: 100, train accuracy: 0.8615, train_loss_norm:0.0218, valid_acc: 0.8474, valid_loss_norm: 0.0409
#  epoch: 150, train accuracy: 0.8749, train_loss_norm:0.0183, valid_acc: 0.8523, valid_loss_norm: 0.0396
#  epoch: 200, train accuracy: 0.8852, train_loss_norm:0.0163, valid_acc: 0.8566, valid_loss_norm: 0.0384
#  epoch: 250, train accuracy: 0.8936, train_loss_norm:0.0149, valid_acc: 0.8612, valid_loss_norm: 0.0372
#  epoch: 300, train accuracy: 0.8995, train_loss_norm:0.0138, valid_acc: 0.8629, valid_loss_norm: 0.0367
# Test accuracy: 0.8718
# Test loss norm: 0.0343
# Current Fold: 5
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8398, train_loss_norm:0.0296, valid_acc: 0.8310, valid_loss_norm: 0.0453
#  epoch: 100, train accuracy: 0.8609, train_loss_norm:0.0218, valid_acc: 0.8477, valid_loss_norm: 0.0408
#  epoch: 150, train accuracy: 0.8746, train_loss_norm:0.0183, valid_acc: 0.8554, valid_loss_norm: 0.0387
#  epoch: 200, train accuracy: 0.8849, train_loss_norm:0.0162, valid_acc: 0.8603, valid_loss_norm: 0.0374
#  epoch: 250, train accuracy: 0.8926, train_loss_norm:0.0148, valid_acc: 0.8655, valid_loss_norm: 0.0360
#  epoch: 300, train accuracy: 0.8995, train_loss_norm:0.0138, valid_acc: 0.8681, valid_loss_norm: 0.0353
# Test accuracy: 0.8712
# Test loss norm: 0.0345
# Current Fold: 6
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8420, train_loss_norm:0.0296, valid_acc: 0.8252, valid_loss_norm: 0.0468
#  epoch: 100, train accuracy: 0.8630, train_loss_norm:0.0217, valid_acc: 0.8431, valid_loss_norm: 0.0420
#  epoch: 150, train accuracy: 0.8755, train_loss_norm:0.0183, valid_acc: 0.8557, valid_loss_norm: 0.0386
#  epoch: 200, train accuracy: 0.8855, train_loss_norm:0.0162, valid_acc: 0.8620, valid_loss_norm: 0.0369
#  epoch: 250, train accuracy: 0.8939, train_loss_norm:0.0148, valid_acc: 0.8675, valid_loss_norm: 0.0355
#  epoch: 300, train accuracy: 0.9001, train_loss_norm:0.0138, valid_acc: 0.8715, valid_loss_norm: 0.0344
# Test accuracy: 0.8623
# Test loss norm: 0.0369
# Current Fold: 7
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8413, train_loss_norm:0.0297, valid_acc: 0.8166, valid_loss_norm: 0.0491
#  epoch: 100, train accuracy: 0.8625, train_loss_norm:0.0218, valid_acc: 0.8327, valid_loss_norm: 0.0448
#  epoch: 150, train accuracy: 0.8755, train_loss_norm:0.0183, valid_acc: 0.8439, valid_loss_norm: 0.0418
#  epoch: 200, train accuracy: 0.8856, train_loss_norm:0.0163, valid_acc: 0.8514, valid_loss_norm: 0.0398
#  epoch: 250, train accuracy: 0.8924, train_loss_norm:0.0149, valid_acc: 0.8577, valid_loss_norm: 0.0381
#  epoch: 300, train accuracy: 0.8988, train_loss_norm:0.0138, valid_acc: 0.8606, valid_loss_norm: 0.0373
# Test accuracy: 0.8721
# Test loss norm: 0.0342
# Current Fold: 8
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8395, train_loss_norm:0.0296, valid_acc: 0.8221, valid_loss_norm: 0.0476
#  epoch: 100, train accuracy: 0.8600, train_loss_norm:0.0218, valid_acc: 0.8399, valid_loss_norm: 0.0429
#  epoch: 150, train accuracy: 0.8735, train_loss_norm:0.0183, valid_acc: 0.8511, valid_loss_norm: 0.0399
#  epoch: 200, train accuracy: 0.8833, train_loss_norm:0.0163, valid_acc: 0.8606, valid_loss_norm: 0.0373
#  epoch: 250, train accuracy: 0.8922, train_loss_norm:0.0149, valid_acc: 0.8698, valid_loss_norm: 0.0349
#  epoch: 300, train accuracy: 0.8987, train_loss_norm:0.0138, valid_acc: 0.8718, valid_loss_norm: 0.0343
# Test accuracy: 0.8629
# Test loss norm: 0.0367
# 1
# Current Fold: 9
# (27841, 300)
# (3479, 300)
# (3479, 300)
#  epoch: 50, train accuracy: 0.8397, train_loss_norm:0.0296, valid_acc: 0.8198, valid_loss_norm: 0.0483
#  epoch: 100, train accuracy: 0.8604, train_loss_norm:0.0217, valid_acc: 0.8370, valid_loss_norm: 0.0436
#  epoch: 150, train accuracy: 0.8749, train_loss_norm:0.0183, valid_acc: 0.8465, valid_loss_norm: 0.0411
#  epoch: 200, train accuracy: 0.8841, train_loss_norm:0.0162, valid_acc: 0.8508, valid_loss_norm: 0.0399
#  epoch: 250, train accuracy: 0.8919, train_loss_norm:0.0148, valid_acc: 0.8574, valid_loss_norm: 0.0382
#  epoch: 300, train accuracy: 0.8985, train_loss_norm:0.0138, valid_acc: 0.8615, valid_loss_norm: 0.0371
# Test accuracy: 0.8684
# Test loss norm: 0.0352
# Average test accuracy over 10 folds: 0.8644725495832135
# Average test loss per example and class over 10 folds: 0.03628625094008461

# %%
def average_out_data_k(data, k=10):
    total_count = len(data)
    count_per_fold = total_count // k # Assumes cleanly divisble number
    new_data = [0.0 for i in range(count_per_fold)]
    for i in range(k):
        for j in range(count_per_fold):
            new_data[j] += data[i * count_per_fold + j]
    new_data = [d / k for d in new_data]
    return new_data

def get_data_at_epoch_fold(data, epoch, total_num_folds=10):
    # Returns a new list of data points at a specified epoch from all folds
    # data = [fold1....fold10]
    # epoch is 0-indexed
    epoch_per_fold = len(data) // total_num_folds
    new_data = [data[f * (epoch_per_fold) + epoch] for f in range(total_num_folds)]
    return new_data # [epoch n from fold1, epoch n from fold2, ..., epoch n from fold10]

# %%
fig, axs = plt.subplots(2, 1, constrained_layout=True)

epochs_error_bar = [50, 100, 150, 200, 250, 300] # 1-indexed
epochs_error_bar_0 = [epoch - 1 for epoch in epochs_error_bar] # 0-indexed

# Plot Loss
average_train_loss = average_out_data_k(train_loss_record)
train_loss_error_bar_y = [average_train_loss[epoch] for epoch in epochs_error_bar_0]
train_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_loss_record, epoch)) for epoch in epochs_error_bar_0]

average_valid_loss = average_out_data_k(holdout_loss_record)
valid_loss_error_bar_y = [average_valid_loss[epoch] for epoch in epochs_error_bar_0]
valid_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_loss_record, epoch)) for epoch in epochs_error_bar_0]

axs[0].plot(average_train_loss, '-b', label='Training loss')
axs[0].errorbar(x=epochs_error_bar_0, y=train_loss_error_bar_y, yerr=train_loss_error_bar_yerr, label='Training loss error', fmt='-b',linestyle='')

axs[0].plot(average_valid_loss, '--r', label='Validation loss')
axs[0].errorbar(x=epochs_error_bar_0, y=valid_loss_error_bar_y, yerr=valid_loss_error_bar_yerr, label='Validation loss error', fmt='--r',linestyle='')

axs[0].legend()
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Normalized Loss')
axs[0].set_title('Loss normalized per example and class vs. Epochs')

# Plot Accuracy
average_train_acc = average_out_data_k(train_accuracy_record)
train_acc_error_bar_y = [average_train_acc[epoch] for epoch in epochs_error_bar_0]
train_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

average_valid_acc = average_out_data_k(holdout_accuracy_record)
valid_acc_error_bar_y = [average_valid_acc[epoch] for epoch in epochs_error_bar_0]
valid_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

axs[1].plot(average_train_acc, '-b', label='Training accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=train_acc_error_bar_y, yerr=train_acc_error_bar_yerr, label='Training accuracy error', fmt='-b',linestyle='')

axs[1].plot(average_valid_acc, '--r', label='Validation accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=valid_acc_error_bar_y, yerr=valid_acc_error_bar_yerr, label='Validation accuracy error', fmt='--r',linestyle='')

axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('Accuracy vs. Epochs')

#plt.savefig("plots/Q6a_i.png")
#plt.close(fig)
# Out:
# Text(0.5, 1.0, 'Accuracy vs. Epochs')

# %%
## (ii) Without PCA on aligned and with PCA on unaligned
## 1. Without PCA on aligned

print("(ii)")
print("Without PCA on aligned")

# Softmax Regression Parameters
lr = 0.5
num_features = X.shape[1]
num_classes = y.max() + 1

train_loss_record = []

train_accuracy_record = []

holdout_loss_record = []

holdout_accuracy_record = []

test_accuracy_record = []

num_epochs = 300
epochs_print = [50, 100, 150, 200, 250, 300]

k = 10

total_test_accuracy = 0.0
total_test_loss = 0.0

cur_fold = 0
for train, valid, test in generate_k_fold_set((X, y), k):
    print(f"Current Fold: {cur_fold}")
    train_data, train_label = train
    valid_data, valid_label = valid
    test_data, test_label = test
    
    train_d = append_bias(train_data)     
    valid_d = append_bias(valid_data)
    test_d = append_bias(test_data)

    softmax_model = SoftmaxRegression(lr, num_features, num_classes)
    best_w = softmax_model.W

    # Onehot encode labels
    y_true = onehot_encode(train_label)
    valid_label_onehot = onehot_encode(valid_label)
    test_label_onehot = onehot_encode(test_label)
    
    for epoch in range(num_epochs):
        y_hat = softmax_model.model(train_d)
        
        raw_train_loss = softmax_model.cross_entropy(y_true, y_hat)
        train_loss_norm = raw_train_loss / len(train_d) / num_classes # train loss normalized by # examples and classes
        
        train_loss_record.append(train_loss_norm)
        
        train_accuracy = softmax_model.accuracy(y_true, y_hat)
        train_accuracy_record.append(train_accuracy)
        
        # TODO: early stopping, plotting std.dev., etc.
        holdout_y = softmax_model.model(valid_d)


        holdout_loss = softmax_model.cross_entropy(holdout_y, valid_label_onehot)
        holdout_loss_norm = holdout_loss / len(valid_d) / num_classes # holdout loss normalized by # examples and classes
        holdout_loss_record.append(holdout_loss_norm)

        holdout_accuracy = softmax_model.accuracy(holdout_y, valid_label_onehot)
        holdout_accuracy_record.append(holdout_accuracy)

        # if holdout_accuracy >= max(holdout_accuracy_record):
        if holdout_accuracy >= max(holdout_accuracy_record[cur_fold * num_epochs:]):
            best_w = softmax_model.W

        # Update Weights
        softmax_model.update_weights(train_d, y_true, y_hat)

        if (epoch + 1) in epochs_print:
            print(f' epoch: {epoch + 1}, train accuracy: {train_accuracy:.4f}, train_loss_norm:{train_loss_norm:.4f}, '\
                f'valid_acc: {holdout_accuracy:.4f}, valid_loss_norm: {holdout_loss_norm:.4f}')

    # Run on Test Dataset
    test_y = softmax_model.model_w(test_d, best_w)

    test_accuracy = softmax_model.accuracy(test_y, test_label_onehot)

    print(f'Test accuracy: {test_accuracy:.4f}')

    total_test_accuracy += test_accuracy

    raw_test_loss = softmax_model.cross_entropy(test_y, test_label_onehot)
    test_loss_norm = raw_test_loss / len(test_d) / num_classes
    total_test_loss += test_loss_norm
    print(f"Test loss norm: {test_loss_norm:.4f}")

    cur_fold += 1

print(f'Average test accuracy over {k} folds: {total_test_accuracy / k}')
print(f'Average test loss per example and class over {k} folds: {total_test_loss / k}')

# %%
fig, axs = plt.subplots(2, 1, constrained_layout=True)

epochs_error_bar = [50, 100, 150, 200, 250, 300] # 1-indexed
epochs_error_bar_0 = [epoch - 1 for epoch in epochs_error_bar] # 0-indexed

# Plot Loss
average_train_loss = average_out_data_k(train_loss_record)
train_loss_error_bar_y = [average_train_loss[epoch] for epoch in epochs_error_bar_0]
train_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_loss_record, epoch)) for epoch in epochs_error_bar_0]

average_valid_loss = average_out_data_k(holdout_loss_record)
valid_loss_error_bar_y = [average_valid_loss[epoch] for epoch in epochs_error_bar_0]
valid_loss_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_loss_record, epoch)) for epoch in epochs_error_bar_0]

axs[0].plot(average_train_loss, '-b', label='Training loss')
axs[0].errorbar(x=epochs_error_bar_0, y=train_loss_error_bar_y, yerr=train_loss_error_bar_yerr, label='Training loss error', fmt='-b')

axs[0].plot(average_valid_loss, '--r', label='Validation loss')
axs[0].errorbar(x=epochs_error_bar_0, y=valid_loss_error_bar_y, yerr=valid_loss_error_bar_yerr, label='Validation loss error', fmt='--r')

axs[0].legend()
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Normalized Loss')
axs[0].set_title('Loss normalized per example and class vs. Epochs')

# Plot Accuracy
average_train_acc = average_out_data_k(train_accuracy_record)
train_acc_error_bar_y = [average_train_acc[epoch] for epoch in epochs_error_bar_0]
train_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(train_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

average_valid_acc = average_out_data_k(holdout_accuracy_record)
valid_acc_error_bar_y = [average_valid_acc[epoch] for epoch in epochs_error_bar_0]
valid_acc_error_bar_yerr = [np.std(get_data_at_epoch_fold(holdout_accuracy_record, epoch)) for epoch in epochs_error_bar_0]

axs[1].plot(average_train_acc, '-b', label='Training accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=train_acc_error_bar_y, yerr=train_acc_error_bar_yerr, label='Training accuracy error', fmt='-b')

axs[1].plot(average_valid_acc, '--r', label='Validation accuracy')
axs[1].errorbar(x=epochs_error_bar_0, y=valid_acc_error_bar_y, yerr=valid_acc_error_bar_yerr, label='Validation accuracy error', fmt='--r')

axs[1].legend()
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('Accuracy vs. Epochs')

plt.savefig("plots/Q6a_ii_1.png")
plt.close(fig)

# %%
## With PCA on unaligned

# %%
## (iii) Confusion Matrix on Test Set results
# TODO

# %%
### Q6(b) - Stochastic Gradient Descent

print("Q6(b) - Stochastic Gradient Descent")

# Softmax Regression Parameters
lr = 0.5
num_features = X.shape[1]
num_classes = y.max() + 1

train_loss_record = []
train_accuracy_record = []
holdout_loss_record = []
holdout_accuracy_record = []
test_accuracy_record = []


# PCA number of principal components
n_components = 300

first_plot = True

num_epochs = 300
epochs_print = [50, 100, 150, 200, 250, 300]

cur_fold = 0

for train, valid, test in generate_k_fold_set((X, y), k = 10):
    print("Cur fold:", cur_fold)
    train_data, train_label = train
    valid_data, valid_label = valid
    test_data, test_label = test
    
    # Project data onto principal components
    pca = PCA(n_components)
    projected = pca.fit_transform(train_data)
    
    # Plot principal components
    if first_plot == True : 
        pca.plot_PC()
        first_plot = False
    train_d = append_bias(projected)     
    valid_d = append_bias(pca.PCA_generate(valid_data))
    test_d = append_bias(pca.PCA_generate(test_data))

    softmax_model = SoftmaxRegression(lr, n_components, num_classes)

    valid_label_onehot = onehot_encode(valid_label)

    # SGD
    for epoch in range(num_epochs):
        print(epoch)
        # Shuffle indices
        indices = np.arange(len(train_d))
        indices = np.random.shuffle(indices)

        train_d = train_d[indices].squeeze(0)
        train_label = train_label[indices].squeeze(0)
        
        # Onehot encode labels
        y_true = onehot_encode(train_label)
            
        # Iterate over each example
        for i in range(len(train_d)):
            cur_ex = train_d[i][np.newaxis, :]
            cur_label = y_true[i][np.newaxis, :]
            y_hat = softmax_model.model(cur_ex)

            # Update Weights
            softmax_model.update_weights(cur_ex, cur_label, y_hat)

        # Training Loss
        y_hat = softmax_model.model(train_d)

        raw_train_loss = softmax_model.cross_entropy(y_true, y_hat)
        train_loss_norm = raw_train_loss / len(train_d) / num_classes

        train_loss_record.append(raw_train_loss)

        train_accuracy = softmax_model.accuracy(y_true, y_hat)
        train_accuracy_record.append(train_accuracy)

        # # Validation Loss
        # holdout_y = softmax_model.model(valid_d)

        # holdout_loss = softmax_model.cross_entropy(holdout_y, valid_label_onehot)
        # holdout_loss_norm = holdout_loss / len(valid_d) / num_classes # holdout loss normalized by # examples and classes
        # holdout_loss_record.append(holdout_loss_norm)

        # holdout_accuracy = softmax_model.accuracy(holdout_y, valid_label_onehot)
        # holdout_accuracy_record.append(holdout_accuracy)

        # if holdout_accuracy >= max(holdout_accuracy_record):
        #     best_w = softmax_model.W

        
        # if (epoch + 1) in epochs_print:
        print(f' epoch: {epoch + 1}, train accuracy: {train_accuracy:.4f}, train_loss_norm:{train_loss_norm:.4f}, '\
            f'valid_acc: {holdout_accuracy:.4f}, valid_loss_norm: {holdout_loss_norm:.4f}')

    # Run on Test Dataset
    test_y = softmax_model.model_w(test_d, best_w)

    test_label_onehot = onehot_encode(test_label)
    test_accuracy = softmax_model.accuracy(test_y, test_label_onehot)

    print(f'Test accuracy: {test_accuracy:.4f}')

    total_test_accuracy += test_accuracy

    raw_test_loss = softmax_model.cross_entropy(test_y, test_label_onehot)
    total_test_loss += raw_test_loss / len(test_d) / num_classes

    cur_fold += 1
# Out:
# Q6(b) - Stochastic Gradient Descent
# Cur fold: 0
# (27841, 300)
# (3479, 300)
# (3479, 300)
# 0
#  epoch: 1, train accuracy: 0.7892, train_loss_norm:0.0837, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 1
#  epoch: 2, train accuracy: 0.7893, train_loss_norm:0.0800, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 2
#  epoch: 3, train accuracy: 0.7895, train_loss_norm:0.0764, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 3
#  epoch: 4, train accuracy: 0.7903, train_loss_norm:0.0730, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 4
#  epoch: 5, train accuracy: 0.7913, train_loss_norm:0.0698, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 5
#  epoch: 6, train accuracy: 0.7921, train_loss_norm:0.0668, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 6
#  epoch: 7, train accuracy: 0.7932, train_loss_norm:0.0641, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 7
#  epoch: 8, train accuracy: 0.7943, train_loss_norm:0.0616, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 8
#  epoch: 9, train accuracy: 0.7958, train_loss_norm:0.0593, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 9
#  epoch: 10, train accuracy: 0.7976, train_loss_norm:0.0572, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 10
#  epoch: 11, train accuracy: 0.7994, train_loss_norm:0.0554, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 11
#  epoch: 12, train accuracy: 0.8014, train_loss_norm:0.0536, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 12
#  epoch: 13, train accuracy: 0.8029, train_loss_norm:0.0521, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 13
#  epoch: 14, train accuracy: 0.8042, train_loss_norm:0.0506, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 14
#  epoch: 15, train accuracy: 0.8059, train_loss_norm:0.0493, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 15
#  epoch: 16, train accuracy: 0.8081, train_loss_norm:0.0480, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 16
#  epoch: 17, train accuracy: 0.8098, train_loss_norm:0.0469, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 17
#  epoch: 18, train accuracy: 0.8114, train_loss_norm:0.0458, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 18
#  epoch: 19, train accuracy: 0.8123, train_loss_norm:0.0448, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 19
#  epoch: 20, train accuracy: 0.8132, train_loss_norm:0.0439, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 20
#  epoch: 21, train accuracy: 0.8151, train_loss_norm:0.0430, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 21
#  epoch: 22, train accuracy: 0.8167, train_loss_norm:0.0422, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 22
#  epoch: 23, train accuracy: 0.8174, train_loss_norm:0.0414, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 23
#  epoch: 24, train accuracy: 0.8184, train_loss_norm:0.0407, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 24
#  epoch: 25, train accuracy: 0.8201, train_loss_norm:0.0400, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 25
#  epoch: 26, train accuracy: 0.8213, train_loss_norm:0.0393, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 26
#  epoch: 27, train accuracy: 0.8225, train_loss_norm:0.0387, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 27
#  epoch: 28, train accuracy: 0.8234, train_loss_norm:0.0381, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 28
#  epoch: 29, train accuracy: 0.8244, train_loss_norm:0.0375, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 29
#  epoch: 30, train accuracy: 0.8250, train_loss_norm:0.0370, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 30
#  epoch: 31, train accuracy: 0.8259, train_loss_norm:0.0365, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 31
#  epoch: 32, train accuracy: 0.8269, train_loss_norm:0.0360, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 32
#  epoch: 33, train accuracy: 0.8279, train_loss_norm:0.0355, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 33
#  epoch: 34, train accuracy: 0.8290, train_loss_norm:0.0350, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 34
#  epoch: 35, train accuracy: 0.8303, train_loss_norm:0.0346, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 35
#  epoch: 36, train accuracy: 0.8314, train_loss_norm:0.0342, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 36
#  epoch: 37, train accuracy: 0.8320, train_loss_norm:0.0338, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 37
#  epoch: 38, train accuracy: 0.8329, train_loss_norm:0.0334, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 38
#  epoch: 39, train accuracy: 0.8334, train_loss_norm:0.0330, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 39
#  epoch: 40, train accuracy: 0.8342, train_loss_norm:0.0326, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 40
#  epoch: 41, train accuracy: 0.8348, train_loss_norm:0.0323, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 41
#  epoch: 42, train accuracy: 0.8355, train_loss_norm:0.0319, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 42
#  epoch: 43, train accuracy: 0.8359, train_loss_norm:0.0316, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 43
#  epoch: 44, train accuracy: 0.8369, train_loss_norm:0.0313, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 44
#  epoch: 45, train accuracy: 0.8376, train_loss_norm:0.0310, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 45
#  epoch: 46, train accuracy: 0.8383, train_loss_norm:0.0307, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 46
#  epoch: 47, train accuracy: 0.8387, train_loss_norm:0.0304, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 47
#  epoch: 48, train accuracy: 0.8389, train_loss_norm:0.0301, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 48
#  epoch: 49, train accuracy: 0.8395, train_loss_norm:0.0298, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 49
#  epoch: 50, train accuracy: 0.8401, train_loss_norm:0.0295, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 50
#  epoch: 51, train accuracy: 0.8408, train_loss_norm:0.0293, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 51
#  epoch: 52, train accuracy: 0.8414, train_loss_norm:0.0290, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 52
#  epoch: 53, train accuracy: 0.8420, train_loss_norm:0.0288, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 53
#  epoch: 54, train accuracy: 0.8422, train_loss_norm:0.0285, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 54
#  epoch: 55, train accuracy: 0.8425, train_loss_norm:0.0283, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 55
#  epoch: 56, train accuracy: 0.8430, train_loss_norm:0.0281, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 56
#  epoch: 57, train accuracy: 0.8435, train_loss_norm:0.0279, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 57
#  epoch: 58, train accuracy: 0.8440, train_loss_norm:0.0277, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 58
#  epoch: 59, train accuracy: 0.8447, train_loss_norm:0.0274, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 59
#  epoch: 60, train accuracy: 0.8453, train_loss_norm:0.0272, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 60
#  epoch: 61, train accuracy: 0.8455, train_loss_norm:0.0270, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 61
#  epoch: 62, train accuracy: 0.8460, train_loss_norm:0.0268, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 62
#  epoch: 63, train accuracy: 0.8463, train_loss_norm:0.0267, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 63
#  epoch: 64, train accuracy: 0.8470, train_loss_norm:0.0265, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 64
#  epoch: 65, train accuracy: 0.8475, train_loss_norm:0.0263, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 65
#  epoch: 66, train accuracy: 0.8479, train_loss_norm:0.0261, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 66
#  epoch: 67, train accuracy: 0.8486, train_loss_norm:0.0259, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 67
#  epoch: 68, train accuracy: 0.8489, train_loss_norm:0.0258, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 68
#  epoch: 69, train accuracy: 0.8494, train_loss_norm:0.0256, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 69
#  epoch: 70, train accuracy: 0.8500, train_loss_norm:0.0254, valid_acc: 0.8661, valid_loss_norm: 0.0359
# 70
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33824/4112494824.py in <module>
#      67
#      68             # Update Weights
# ---> 69             softmax_model.update_weights(cur_ex, cur_label, y_hat)
#      70
#      71         # Training Loss
#
# c:\Users\Victor\OneDrive\Documents\UCSD\0CSE251B\hw1\CSE251B\cse251b_PA1_starter\model\softmax.py in update_weights(self, X, y_true, y_hat)
#      77         y_hat: predicted labels
#      78         '''
# ---> 79         grad_w = np.dot(X.T, (y_hat - y_true))
#      80         grad_b = np.sum(y_hat - y_true)
#      81
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
### (c) Visualize the weights

def weights2range(w, min=0, max=256):
    # Scales weights to be between min and max
    w /= np.max(w)
    w *= (max)
    w += min
    return w

# Plot image
